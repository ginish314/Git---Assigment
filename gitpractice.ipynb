# %%
#

# %% [markdown]
# # QUESTION - 1 1 Based on what you have learnt in the class, do the following steps:
#
# #a. Create a new folde
#
# :-  mkdir gitpractice
#
#     cd gitpractice
#
# #b Put the following files in the folder
# Code.txt
#
# Log.txt
#
# Output.txt
#
# :-   touch Code.txt Log.txt Output.txt
#
# # c. Stage the Code.txt and Output.txt files
#
# :-  get init
#
# & for stage the 2 file we will use add command
#
# "git add code.txt outoutput.txt" (we can use the git add . for add all the files )
#
# than we will check the status where we can check is tracable or not
#
# "git status"
#
#
# #d. Commit them
#
# git commit -m "Add Code.txt and Output.txt"
#
#
# #e. And finally push them to GitHub
# :- for push to git hub we will create a repository name "gitpractice" and copy the link and paste
#
# "git remote add origin https://github.com/ginish314/gitpractice.git"
#
# than we will use this command to replace user name to actual GitHub username
#
# "git push -u origin master"

# %% [markdown]
# # QUESTION 2 Tasks to Be Performed:
#
#
# #1. Create a Git working directory with feature1.txt and feature2.txt in the master branch
#
# :-FOR CREATE A DIRECTORY WE WILL USE THIS COMMONAD
#
# " mkdir gitfeature "
#
# AND FOR CHANGE THE DIRECTORY WE WILL USE THIS COMMONAD
#
# " cd gitfeature "
#
# THAN WE WILL CREATE feature1.txt and feature2.txt
#
# " touch feature1.txt feature2.txt "
#
# THAN
#
# " git init "
#
# git commit -m "add feature1.txt and feature2.txt to master branch"
#
# WE CAN USE THIS COMMONAD TO CHECK
#
# "git log"
#
#
# #2. Create 3 branches develop, feature1 and feature2
#
# :- WE WILL USE THIS COMMANT
#
# "git branch develop"
#
# "git branch feature1 develop"
#
# "git branch feature2 develop"
#
#
# View all branches : "git branch"
#
#
#
#
#
# #3. In develop branch create develop.txt, do not stage or commit it
#
# WE WILL USE THIS COMMAND
#
# "git develop "
#
#  AND FOR CREATE
#
#  "touch develop.txt"
#
#
# #4. Stash this file and check out to feature1 branch
#
# :- FOR STASH THE FILE AND CHECKOUT
#
# "git stash -u "
#
# AND
#
# "git checkout feature1"
#
# #5. Create new.txt file in feature1 branch, stage and commit this file
#
# :- "touch new.txt"
#
#
# "git add new.txt"
#
#
# git commit -m "Add new.txt in feature1 branch"
#
# #6. Checkout to develop, unstash this file and commit
#
# :- "git checkout develop"
#
#
# "git stash pop" (to check the untracked files)
#
# "git add develop.txt"
#
# git commit -m "Add develop.txt in develop branch"
#
# #7. Please submit all the Git commands used to do the above step
#
# :- " mkdir gitfeature "
#
#
# " cd gitfeature "
#
# " touch feature1.txt feature2.txt "
#
# git add feature1.txt feature2.txt
#
# git commit -m "Add feature1.txt and feature2.txt to master branch"
#
# BRANCH
#
#
# "git branch develop"
#
# "git branch feature1 develop"
#
# "git branch feature2 develop"
#
# THAN
#
# "git checkout develop"
#
# "touch develop.txt"
#
# "git stash -u"
#
# "git checkout feature1"
#
# touch new.txt
#
# git add new.txt
#
# git commit -m "Add new.txt in feature1 branch"
#
#
# git checkout develop
#
# git stash pop
#
# git add develop.txt
#
# git commit -m "Add develop.txt in develop branch"

# %% [markdown]
# # QUESTION 3- Create a Git working directory, with the following branches:
#
#
#                Develop
#
#                F1
#
#                f2
# : - mkdir newdirectory
#
#   cd newdirectory
#
#   git init
#
#   FOR CREATE NEW FILE
#
#   touch readme.md
#
#   git add readme.md
#
#   git commit -m "add readme.md to master"
#
#   (FOR CREATE THE BRANCH)
#
#   git branch devlop
#
#   git branch devlopF1
#
#   git branch devlopF2
#
#
#
# #2. In the master branch, commit main.txt file
#
# :- HERE IS COMMANDS
#
# git checkout master (to move to master branch)
#
# touch main.txt(to create txt file)
#
# git add main.txt
#
# git commit -m "add main.txt to master branch"
#
# #3. Put develop.txt in develop branch, f1.txt and f2.txt in f1 and f2 respectively
#
# :- HERE IS COMMAND
#
# git checkout develop branch
#
# touch develop.txt
#
# git add develop.txt
#
# git commit -m "add develop.txt to develop branch"
#
# (FOR f1 and f2 brach we will create branch )
#
# git branch f1
#
# git checkout f1
#
# touch f1.txt
#
# git add f1.txt
#
# git commit -m "add f1.txt to f1 branch"
#
# git branch f2
#
# git checkout f2
#
# touch f2.txt
#
# git add f2.txt
#
# git commit -m "add f2.txt to f2 branch"
#
#
#
# #4. Push all these branches to GitHub
#
# :- FIRSTLY WE WILL CREATE GITHUB REPO
#
# https://github.com/ginish314/gitrepo.git
#
# AND PUSH ALL THE BRANCHES TO GITHUB
#
# git push -u origin master
#
# TERMINAL ASKING FOR USER NAME AND PASSWORD AFTER THAT
#
# git push -u origin devolop
#
# git push -u orgin f1 branch
#
# git push -u orgin f2 branch
#
# #5. On local delete f2 branch
#
# :- FOR DELET THE f2 branch we will use this command
#
# git branch -d f2 branch
#
# #6. Delete the same branch on GitHub as well
#
# git push origin --delete f2

# %% [markdown]
# #QUESTION -4  Tasks to Be Performed:
#
# #1. Put master.txt on master branch, stage and commit
# :- WE WILL THIS COMMANDS
#
# git checkout master
#
# touch master.txt
#
# git add master.txt
#
# git commit -m "Add master.txt to master branch"
#
# #2. Create 3 branches: public 1, public 2 and private
# :- git checkout master (switched to master)
#
# git checkout -b public1
#
# git checkout -b public2
#
# git checkout -b private
#
# #3. Put public1.txt on public 1 branch, stage and commit
#
# git checkout public1
#
# touch public.txt
#
# git add public1.txt
#
# git commit -m "add public1 to public1 branch
#
# #4. Merge public 1 on master branch
#
# git checkout master
#
# git marge public1
#
# #5. Merge public 2 on master branch
#
# git checkout master
#
# git marge to public2
#
# #6. Edit master.txt on private branch, stage and commit
#
# git checkout private
#
# nano master.txt ( edit the txt file and contorl+x and then y than enter)
#
# git add master.txt
#
# git commit -m "add master.txt to private"
#
# #7. Now update branch public 1 and public 2 with new master code in private
#
# :- git checkout public1
#
# git merge private -m "Merge update to prive to public1"
#
# FOR public2
#
# git checkout public2
#
# git merge private -m "Merge update to prive to public1"
#
#
# ##8. Also update new master code on master
# :-
# git checkout master
#
# git merge private
#
#
# 9. Finally update all the code on the private branch
#
# :- FOR UPDATE AND MERGE WE WILL USE THIS COMMAND
#
# git checkout private
#
# git merge master -m "merge master into private"
#
# git merge public1 -m "merge public1 into private"
#
# git merge public2 -m "merger public2 into private"

# %% [markdown]
# # QUESTION 5- Tasks to Be Performed:
#
# 1. Create a Git Flow workflow architecture on Git
#
# :- Create a new branch from develop:
#
# git checkout develop
#
# git checkout -b feature
#
# "Merge the feature branch back into develop"
#
# git checkout develop
#
# git merge feature
#
# git branch -d feature
#
# "create a branch"
#
# git checkout develop
#
# git checkout -b release
#
# then marge
#
# git checkout main
#
# git merge release/1.0.0
#
# git tag -a v1.0.0
#
# git checkout develop
#
# git merge release/1.0.0
#
# git branch -d release/1.0.0
#
# Create a hotfix branch from main:-
#
# git checkout main
#
# git checkout -b hotfix/1.0.1
#
# Merge the hotfix branch into both main and develop:
#
#
# git checkout main
#
# git merge hotfix/1.0.1
#
# git tag -a v1.0.1
#
# git checkout develop
#
# git merge hotfix/1.0.1
#
# git branch -d hotfix/1.0.1
#
# 2. Create all the required branches
# :- git init
#
# git checkout -b main
#
# git checkout -b develop
#
# "PUSH THE BRANCHES "
#
# git push -u orgin main
#
# git push -u orgin develop
#
# " CREATE FEATURE BRANCH"
#
# git checkout  develop
#
# git checkout -n feature
#
# "MARGE"
#
# git checkout develop
#
# git merge feature
#
# git branch -d feature
#
# " CREATE RELEASE BRANCHES"
#
# git checkout develop
#
# git checkout -b release
#
# "Merge "
#
# git checkout main
#
# git merege relaese
#
# git tag -a vX.Y.Z -m "release version X.Y.Z"
#
# git checkout develop
#
# git merge release
#
# git checkout main
#
# git checkout -b hotfix/hotfix-name
#
# "MEREGE"
#
# git checkout main
#
# git merge hotfix/hotfix-name
#
# git tag -a vX.Y.Z -m "Hotfix version X.Y.Z"
#
# git checkout develop
#
# git merge hotfix/hotfix-name
#
# git branch -d hotfix/hotfix-name
#
#
# 3. starting from e feature branch, push the branch to the master, following the architecture
#
# :- "Feature Branch to develop"
#
# git checkout develop
#
# git checkout -b feature
#
# "WILL ADD "
#
# git add .
#
# git commit -m "feature xyz"
#
# "WILL PUSH"
#
# git push -u origin feature
#
# "WILL MEREGE"
#
# git checkout develop
#
# git merge feature
#
# git branch -d feature
#
# " WILL PUSH TO DEVELOP"
#
# git push orgin develop
#
#
#
# 4. Push an urgent.txt on master using hotfix
#
# :-"creating a hotfix branch from the master branch."
#
# git checkout master
#
# git checkout -b hotfix
#
# "WILL CREATE TXT FILE "
#
# echo "This is new txt file." > file.txt
#
# git add file.txt
#
# git commit -m "Add file.txt for immediate fix"
#
# "PUSH TO HOTFIX BRANCH"
#
# git push -u origin hotfix
#
#
# git checkout master
#
# git merge --no-ff hotfix
#
# git tag -a v1.0.1 -m "Hotfix: file.txt added"
#
# git checkout develop
#
# git merge hotfix
#
# git branch -d hotfix
#
# "PUSH TO REMOTE"
#
# git push origin master
#
# git push origin develop
#
# git push origin --tags
